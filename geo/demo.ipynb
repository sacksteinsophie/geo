# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.mlab as ml

ndata = 10
ny, nx = 100, 200
xmin, xmax = 1, 10
ymin, ymax = 1, 10
# x = np.linspace(1, 10, ndata)
# y = np.linspace(1, 10, ndata)

x = np.random.randint(xmin, xmax, ndata)
y = np.random.randint(ymin, ymax, ndata)
z = np.random.random(ndata)

xi = np.linspace(xmin, xmax, nx)
yi = np.linspace(ymin, ymax, ny)
zi = ml.griddata(x, y, z, xi, yi)

plt.contour(xi, yi, zi, 10, linewidths = 1, colors = 'k')
plt.pcolormesh(xi, yi, zi, cmap = plt.get_cmap('rainbow'))

plt.colorbar() 
plt.scatter(x, y, marker = 'o', c = 'b', s = 5, zorder = 10)
plt.xlim(xmin, xmax)
plt.ylim(ymin, ymax)
plt.show()
# Out:
# /Users/sophiesackstein/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: MatplotlibDeprecationWarning: The griddata function was deprecated in version 2.2.

# %%
# !python -mpip install git+https://github.com/matplotlib/natgrid.git
# Out:
# Collecting git+https://github.com/matplotlib/natgrid.git
#   Cloning https://github.com/matplotlib/natgrid.git to /private/var/folders/86/gqt6ghjj03q76jl342z9844w0000gn/T/pip-req-build-kd6yd821
#   Running command git clone -q https://github.com/matplotlib/natgrid.git /private/var/folders/86/gqt6ghjj03q76jl342z9844w0000gn/T/pip-req-build-kd6yd821
# Building wheels for collected packages: natgrid
#   Building wheel for natgrid (setup.py) ... done
#   Created wheel for natgrid: filename=natgrid-0.2.1-cp36-cp36m-macosx_10_7_x86_64.whl size=43768 sha256=d8e67a82042533e72a4afdeb68e479cccdae6b2bb93af744eca44020dfe0d561
#   Stored in directory: /private/var/folders/86/gqt6ghjj03q76jl342z9844w0000gn/T/pip-ephem-wheel-cache-x7857_ij/wheels/7e/97/0a/6c16951f2d41a8c8f462d006358a713c3a37b130b561430e76
# Successfully built natgrid
# Installing collected packages: natgrid
# Successfully installed natgrid-0.2.1
